# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn import preprocessing

from numpy import sort
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.model_selection import RandomizedSearchCV

# %%
train = pd.read_csv('data/other-cleaned_train.csv')
test = pd.read_csv('data/other-cleaned_test.csv')

# %%
X_train = train.copy()
X_train.drop(columns=['Opportunity_Created_Year', 'Month', 'Account_Created_Date', 'Unnamed: 0', 'Target'], inplace=True)

# %%
Region = list(train['Region'])
le = preprocessing.LabelEncoder()
Region_codificada = le.fit_transform(Region)
X_train['Region'] = Region_codificada

Territory = list(train['Territory'])
le = preprocessing.LabelEncoder()
Territory_codificada = le.fit_transform(Territory)
X_train['Territory'] = Territory_codificada

Billing_Country = list(train['Billing_Country'])
le = preprocessing.LabelEncoder()
Billing_Country_codificada = le.fit_transform(Billing_Country)
X_train['Billing_Country'] = Billing_Country_codificada

Account_Name = list(train['Account_Name'])
le = preprocessing.LabelEncoder()
Account_Name_codificada = le.fit_transform(Account_Name)
X_train['Account_Name'] = Account_Name_codificada

Account_Owner = list(train['Account_Owner'])
le = preprocessing.LabelEncoder()
Account_Owner_codificada = le.fit_transform(Account_Owner)
X_train['Account_Owner'] = Account_Owner_codificada

Opportunity_Type = list(train['Opportunity_Type'])
le = preprocessing.LabelEncoder()
Opportunity_Type_codificada = le.fit_transform(Opportunity_Type)
X_train['Opportunity_Type'] = Opportunity_Type_codificada

Quote_Type = list(train['Quote_Type'])
le = preprocessing.LabelEncoder()
Quote_Type_codificada = le.fit_transform(Quote_Type)
X_train['Quote_Type'] = Quote_Type_codificada

Account_Type = list(train['Account_Type'])
le = preprocessing.LabelEncoder()
Account_Type_codificada = le.fit_transform(Account_Type)
X_train['Account_Type'] = Account_Type_codificada

Opportunity_Owner = list(train['Opportunity_Owner'])
le = preprocessing.LabelEncoder()
Opportunity_Owner_codificada = le.fit_transform(Opportunity_Owner)
X_train['Opportunity_Owner'] = Opportunity_Owner_codificada

Delivery_Terms = list(train['Delivery_Terms'])
le = preprocessing.LabelEncoder()
Delivery_Terms_codificada = le.fit_transform(Delivery_Terms)
X_train['Delivery_Terms'] = Delivery_Terms_codificada

Currency = list(train['Currency'])
le = preprocessing.LabelEncoder()
Currency_codificada = le.fit_transform(Currency)
X_train['Currency'] = Currency_codificada

Last_Modified_By = list(train['Last_Modified_By'])
le = preprocessing.LabelEncoder()
Last_Modified_By_codificada = le.fit_transform(Last_Modified_By)
X_train['Last_Modified_By'] = Last_Modified_By_codificada

Product_Family = list(train['Product_Family'])
le = preprocessing.LabelEncoder()
Product_Family_codificada = le.fit_transform(Product_Family)
X_train['Product_Family'] = Product_Family_codificada

Product_Name = list(train['Product_Name'])
le = preprocessing.LabelEncoder()
Product_Name_codificada = le.fit_transform(Product_Name)
X_train['Product_Name'] = Product_Name_codificada

ASP_Currency = list(train['ASP_Currency'])
le = preprocessing.LabelEncoder()
ASP_Currency_codificada = le.fit_transform(ASP_Currency)
X_train['ASP_Currency'] = ASP_Currency_codificada

ASP_converted_Currency = list(train['ASP_(converted)_Currency'])
le = preprocessing.LabelEncoder()
ASP_converted_Currency_codificada = le.fit_transform(ASP_converted_Currency)
X_train['ASP_(converted)_Currency'] = ASP_converted_Currency_codificada

Delivery_Quarter = list(train['Delivery_Quarter'])
le = preprocessing.LabelEncoder()
Delivery_Quarter_codificada = le.fit_transform(Delivery_Quarter)
X_train['Delivery_Quarter'] = Delivery_Quarter_codificada

Total_Amount_Currency = list(train['Total_Amount_Currency'])
le = preprocessing.LabelEncoder()
Total_Amount_Currency_codificada = le.fit_transform(Total_Amount_Currency)
X_train['Total_Amount_Currency'] = Total_Amount_Currency_codificada

Total_Taxable_Amount_Currency = list(train['Total_Taxable_Amount_Currency'])
le = preprocessing.LabelEncoder()
Total_Taxable_Amount_Currency_codificada = le.fit_transform(Total_Taxable_Amount_Currency)
X_train['Total_Taxable_Amount_Currency'] = Total_Taxable_Amount_Currency_codificada

Prod_Category_A = list(train['Prod_Category_A'])
le = preprocessing.LabelEncoder()
Prod_Category_A_codificada = le.fit_transform(Prod_Category_A)
X_train['Prod_Category_A'] = Prod_Category_A_codificada

Bureaucratic_Code = list(train['Bureaucratic_Code'])
le = preprocessing.LabelEncoder()
Bureaucratic_Code_codificada = le.fit_transform(Bureaucratic_Code)
X_train['Bureaucratic_Code'] = Bureaucratic_Code_codificada

Delivery_Quarter_of_Year = list(train['Delivery_Quarter_of_Year'])
le = preprocessing.LabelEncoder()
Delivery_Quarter_of_Year_codificada = le.fit_transform(Delivery_Quarter_of_Year)
X_train['Delivery_Quarter_of_Year'] = Delivery_Quarter_of_Year_codificada

Region_Territory_Country = list(train['Region_Territory_Country'])
le = preprocessing.LabelEncoder()
Region_Territory_Country_codificada = le.fit_transform(Region_Territory_Country)
X_train['Region_Territory_Country'] = Region_Territory_Country_codificada

Product_Family_Name = list(train['Product_Family_Name'])
le = preprocessing.LabelEncoder()
Product_Family_Name_codificada = le.fit_transform(Product_Family_Name)
X_train['Product_Family_Name'] = Product_Family_Name_codificada

Quote_Expiry_DOY = list(train['Quote_Expiry_DOY'])
le = preprocessing.LabelEncoder()
Quote_Expiry_DOY_codificada = le.fit_transform(Quote_Expiry_DOY)
X_train['Quote_Expiry_DOY'] = Quote_Expiry_DOY_codificada

Quote_Expiry_Year = list(train['Quote_Expiry_Year'])
le = preprocessing.LabelEncoder()
Quote_Expiry_Year_codificada = le.fit_transform(Quote_Expiry_Year)
X_train['Quote_Expiry_Year'] = Quote_Expiry_DOY_codificada

Planned_Delivery_End_DOY = list(train['Planned_Delivery_End_DOY'])
le = preprocessing.LabelEncoder()
Planned_Delivery_End_DOY_codificada = le.fit_transform(Planned_Delivery_End_DOY)
X_train['Planned_Delivery_End_DOY'] = Planned_Delivery_End_DOY_codificada

Planned_Delivery_End_Year = list(train['Planned_Delivery_End_Year'])
le = preprocessing.LabelEncoder()
Planned_Delivery_End_Year_codificada = le.fit_transform(Planned_Delivery_End_Year)
X_train['Planned_Delivery_End_Year'] = Planned_Delivery_End_Year_codificada


X_train["Total_Amount"] = pd.to_numeric(train["Total_Amount"],errors='coerce').fillna(X_train["Total_Amount"].mean())

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, train.Target, test_size=0.33, random_state=7)

# %%
model = XGBClassifier(use_label_encoder=False)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
logloss = log_loss(y_test, predictions)
print("Accuracy: %.2f%%, logloss:%.2f" % (accuracy * 100.0,logloss))

thresholds = sort(model.feature_importances_)
for thresh in thresholds:
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(x_train)
 
    selection_model = XGBClassifier(use_label_encoder =False)
    selection_model.fit(select_X_train, y_train)
    
    select_X_test = selection.transform(x_test)
    y_pred = selection_model.predict(select_X_test)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(y_test, predictions)
    logloss = log_loss(y_test, predictions)
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%, Logloss: %.2f" % (thresh, select_X_train.shape[1], accuracy*100.0, logloss))
# Out:
# Accuracy: 82.74%, logloss:5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.000, n=52, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.001, n=37, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.007, n=36, Accuracy: 82.80%, Logloss: 5.94
# Thresh=0.007, n=35, Accuracy: 82.80%, Logloss: 5.94
# Thresh=0.007, n=34, Accuracy: 82.95%, Logloss: 5.89
# Thresh=0.008, n=33, Accuracy: 82.49%, Logloss: 6.05
# Thresh=0.008, n=32, Accuracy: 82.83%, Logloss: 5.93
# Thresh=0.008, n=31, Accuracy: 82.89%, Logloss: 5.91
# Thresh=0.009, n=30, Accuracy: 82.64%, Logloss: 6.00
# Thresh=0.009, n=29, Accuracy: 82.80%, Logloss: 5.94
# Thresh=0.009, n=28, Accuracy: 82.80%, Logloss: 5.94
# Thresh=0.009, n=27, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.013, n=26, Accuracy: 82.74%, Logloss: 5.96
# Thresh=0.015, n=25, Accuracy: 82.70%, Logloss: 5.97
# Thresh=0.015, n=24, Accuracy: 82.58%, Logloss: 6.02
# Thresh=0.015, n=23, Accuracy: 82.61%, Logloss: 6.01
# Thresh=0.015, n=22, Accuracy: 82.02%, Logloss: 6.21
# Thresh=0.016, n=21, Accuracy: 82.30%, Logloss: 6.11
# Thresh=0.017, n=20, Accuracy: 81.93%, Logloss: 6.24
# Thresh=0.018, n=19, Accuracy: 82.15%, Logloss: 6.17
# Thresh=0.018, n=18, Accuracy: 82.05%, Logloss: 6.20
# Thresh=0.018, n=17, Accuracy: 81.99%, Logloss: 6.22
# Thresh=0.019, n=16, Accuracy: 81.68%, Logloss: 6.33
# Thresh=0.019, n=15, Accuracy: 81.75%, Logloss: 6.31
# Thresh=0.020, n=14, Accuracy: 81.37%, Logloss: 6.43
# Thresh=0.021, n=13, Accuracy: 81.31%, Logloss: 6.45
# Thresh=0.021, n=12, Accuracy: 80.66%, Logloss: 6.68
# Thresh=0.025, n=11, Accuracy: 80.32%, Logloss: 6.80
# Thresh=0.026, n=10, Accuracy: 80.14%, Logloss: 6.86
# Thresh=0.030, n=9, Accuracy: 79.02%, Logloss: 7.25
# Thresh=0.032, n=8, Accuracy: 79.58%, Logloss: 7.05
# Thresh=0.033, n=7, Accuracy: 78.71%, Logloss: 7.35
# Thresh=0.034, n=6, Accuracy: 76.79%, Logloss: 8.01
# Thresh=0.035, n=5, Accuracy: 77.13%, Logloss: 7.90
# Thresh=0.041, n=4, Accuracy: 75.96%, Logloss: 8.30
# Thresh=0.087, n=3, Accuracy: 74.38%, Logloss: 8.85
# Thresh=0.133, n=2, Accuracy: 72.90%, Logloss: 9.36
# Thresh=0.181, n=1, Accuracy: 72.00%, Logloss: 9.67

# %%
fig = plt.gcf()
fig.set_size_inches(350, 350)
selection = SelectFromModel(model, threshold=0.040, prefit=True)
selected_dataset = selection.transform(x_train)
xgb.plot_importance(booster=model)

plt.rcParams["figure.figsize"] = (40,20)
plt.xlabel("\nFeature importance", fontsize=40)
plt.ylabel("Features", fontsize=35)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
params={
    'n_estimators':stats.randint(10,500),
    'learning_rate':stats.uniform(0.01,0.3),
    'subsample':stats.uniform(0.3,0.7),
    'min_child_weight':[1,5,10],
    'max_depth':[3,10,6],
    'gamma':stats.randint(0,10),
    'colsample_bytree':stats.uniform(0.,0.6)
}

xgboost_search = RandomizedSearchCV(xgb.XGBClassifier(n_jobs=-1),
                          param_distributions=params,
                          cv=2,
                          scoring='neg_log_loss',
                          verbose=1,
                          n_iter=100)

# %%
xgboost_search.fit(x_train,y_train)
# Out:
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  4.5min finished
# RandomizedSearchCV(cv=2, estimator=XGBClassifier(n_jobs=-1), n_iter=100,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fee50118310>,
#                                         'gamma': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fee50118450>,
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fee4ef9cdd0>,
#                                         'max_depth': [3, 10, 6],
#                                         'min_child_weight': [1, 5, 10],
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fee4ef9ce50>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fee50118990>},
#                    scoring='neg_log_loss', verbose=1)

# %%
y_pred = xgboost_search.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
logloss = log_loss(y_test, predictions)
print("Accuracy: %.2f%%, logloss:%.2f" % (accuracy * 100.0,logloss))

thresholds = sort(xgboost_search.best_estimator_.feature_importances_)
for thresh in thresholds:
    selection = SelectFromModel(xgboost_search.best_estimator_, threshold=thresh, prefit=True)
    select_X_train = selection.transform(x_train)
 
    selection_model = RandomizedSearchCV(xgb.XGBClassifier(n_jobs=-1),
                          param_distributions=params,
                          cv=2,
                          scoring='neg_log_loss',
                          verbose=1,
                          n_iter=100)
    
    selection_model.fit(select_X_train, y_train)
    
    select_X_test = selection.transform(x_test)
    y_pred = selection_model.predict(select_X_test)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(y_test, predictions)
    logloss = log_loss(y_test, predictions)
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%, Logloss: %.2f" % (thresh, select_X_train.shape[1], accuracy*100.0, logloss))
# Out:
# Accuracy: 85.27%, logloss:5.09
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  4.3min finished
# Thresh=0.000, n=52, Accuracy: 85.67%, Logloss: 4.95
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  5.4min finished
# Thresh=0.000, n=52, Accuracy: 86.39%, Logloss: 4.70
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  5.6min finished
# Thresh=0.000, n=52, Accuracy: 86.85%, Logloss: 4.54
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  4.5min finished
# Thresh=0.006, n=49, Accuracy: 85.77%, Logloss: 4.92
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
