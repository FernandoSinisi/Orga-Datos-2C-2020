# %%
import pandas as pd

from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score

from sklearn import model_selection, metrics, preprocessing, neighbors

# %%
df_train = pd.read_csv('../../Feature_Encoding/data/train_glmm_encoding.csv')
df_test = pd.read_csv('../../Feature_Encoding/data/test_glmm_encoding.csv')
train = pd.read_csv('../../Feature_Engineering/data/other-cleaned_train.csv')

# %%
def cross_val(model, x_train, y_train):
    score_cross_val = model_selection.cross_val_score(model, x_train, y_train, cv=5)
    print(score_cross_val.mean())

# %%
def test_model(model, x_test, y_test):
    predictions = model.predict_proba(x_test)[:,1]
    logloss = metrics.log_loss(y_test, predictions)
    accuracy = metrics.accuracy_score(y_test, predictions.round())
    print("Accuracy: %.2f%%, Logloss: %.2f" % (accuracy*100.0, logloss))

# %%
#Realiza busqueda completa combinando los parametros
def knn(x_train, y_train, x_validation, y_validation):
    knn_classifier = neighbors.KNeighborsClassifier()
    params_knn = {'weights':['uniform','distance'],'leaf_size':[10,15,30,45],'n_neighbors':[5,10,25,50],'p':[1,2,3,4]}    
    knn_gs = model_selection.GridSearchCV(knn_classifier, params_knn, cv=2,verbose=3)
    knn_gs.fit(x_train, y_train)
    knn_best = knn_gs.best_estimator_
    print(knn_gs.best_params_)
    print('knn: {}'.format(knn_best.score(x_validation, y_validation)))
    return knn_best

# %%
y = train.Target
x_train, x_validation, y_train, y_validation = model_selection.train_test_split(df_train, y, test_size=0.3, stratify=y)

# %%
#Para normalizar las columnas
normalized_mean = preprocessing.normalize(df_train,axis=0)

y = train.Target
normalized_x_train, normalized_x_validation, normalized_y_train, normalized_y_validation_mean_encoding = model_selection.train_test_split(normalized_mean, y, test_size=0.3, stratify=y)

# %%
knn_ = knn(x_train, y_train, x_validation, y_validation)
test_model(knn_, x_validation, y_validation)
cross_val(knn_, x_train, y_train)
# Out:
# Fitting 2 folds for each of 128 candidates, totalling 256 fits
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   3.0s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   3.6s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   2.9s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   3.2s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   1.7s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time= 1.1min
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time= 1.5min
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time=  41.5s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time=  36.0s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time=  35.9s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time=  35.4s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time=  33.9s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time=  34.0s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   2.1s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   2.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   2.0s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   2.1s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   1.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time=  34.4s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time=  34.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time=  34.0s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time=  34.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time=  34.3s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time=  34.3s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time=  34.0s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time=  34.1s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   2.2s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   2.2s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   2.0s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   2.1s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   1.2s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time=  34.3s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time=  34.8s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time=  34.1s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time=  34.1s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time=  34.3s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time=  34.4s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time=  34.1s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time=  36.6s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   2.8s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   2.5s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   2.6s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   1.3s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time=  37.6s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time= 1.0min
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time=  34.4s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time=  30.9s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time=  33.0s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time=  35.7s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time=  35.1s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time=  33.8s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   1.7s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   1.7s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   1.5s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   1.6s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   1.2s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time=  48.4s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time=  50.7s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time=  54.7s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time= 1.1min
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time= 1.1min
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time= 1.2min
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time= 1.2min
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time= 1.1min
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   3.7s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   3.2s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   3.0s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   2.9s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   1.6s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   1.5s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   1.2s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   1.3s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time=  48.7s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time=  51.6s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time=  47.4s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time=  46.9s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time=  46.8s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time=  46.6s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time=  46.0s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time=  46.7s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   2.7s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   2.6s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time=  46.3s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time=  46.5s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time=  46.1s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time=  46.2s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time=  45.7s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time=  46.2s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time=  46.0s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time=  46.1s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   2.6s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   2.1s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   2.6s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time=  45.8s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time=  46.5s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time=  45.8s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time=  46.1s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time=  46.1s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time=  46.4s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time=  46.3s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time=  45.8s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   2.6s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   2.7s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   2.5s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   2.5s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time=  46.0s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time=  46.1s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time=  45.9s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time=  46.0s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time=  46.4s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time=  46.2s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time=  46.4s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time=  45.9s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   2.6s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   2.7s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time=  45.9s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time=  46.3s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time=  47.5s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time=  46.0s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time=  46.2s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time=  46.5s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time=  45.9s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time=  45.5s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   2.6s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   2.8s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   2.1s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time=  46.5s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time=  46.5s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time=  46.0s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time=  46.2s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time=  46.2s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time=  46.0s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time=  46.2s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time=  46.3s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   2.9s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   2.6s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   1.2s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time=  46.5s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time=  46.5s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time=  46.0s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time=  46.2s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time=  46.4s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time=  46.7s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time=  46.2s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time=  46.4s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   2.8s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   2.8s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   2.2s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   2.5s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time=  45.9s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time=  46.3s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time=  45.4s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time=  46.1s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time=  46.5s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time=  46.2s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time=  45.9s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time=  46.6s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   2.8s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   2.2s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   2.5s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time=  46.3s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time=  46.4s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time=  46.5s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time=  45.6s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time=  46.2s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time=  46.4s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time=  45.7s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time=  45.6s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   2.5s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   2.5s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   2.6s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   1.4s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time=  46.4s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time=  46.3s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time=  46.0s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time=  46.3s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time=  46.6s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time=  46.3s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time=  45.8s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time=  46.2s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   2.7s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   2.6s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time=  46.0s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time=  45.9s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time=  45.8s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time=  46.0s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time=  46.5s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time=  46.6s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time=  46.2s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time=  46.6s
# {'leaf_size': 10, 'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# knn: 0.7751233958538993
# Accuracy: 77.51%, Logloss: 0.52
# 0.7804189732716663

# %%
normalized_knn = knn(x_train, y_train, x_validation, y_validation)
test_model(normalized_knn, x_validation, y_validation)
cross_val(normalized_knn, x_train, y_train)
# Out:
# Fitting 2 folds for each of 128 candidates, totalling 256 fits
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   2.8s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   2.8s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   2.5s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time=  44.7s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time=  44.6s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time=  44.0s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time=  44.6s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time=  44.6s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time=  42.5s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time=  39.1s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   1.6s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time=  39.0s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time=  39.2s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time=  39.5s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   2.0s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time=  40.0s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time=  39.8s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time=  40.7s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time=  40.2s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time=  39.9s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   2.0s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   1.8s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   1.2s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time=  39.6s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time=  39.5s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time=  39.5s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time=  39.6s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time=  39.7s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time=  39.7s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   0.8s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time=  39.2s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time=  39.2s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time=  39.1s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time=  39.6s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   1.6s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time=  39.2s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time=  39.2s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time=  39.3s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time=  39.1s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time=  39.1s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time=  39.2s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   1.6s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   0.8s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time=  39.1s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time=  38.9s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   0.9s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time=  39.2s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time=  39.0s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time=  39.1s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time=  39.1s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time=  39.6s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time=  39.2s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   1.6s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time=  39.0s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time=  39.4s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time=  39.3s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time=  39.6s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time=  39.0s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time=  39.3s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   2.1s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   0.8s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time=  39.6s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time=  39.1s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time=  39.3s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time=  39.4s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time=  39.2s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time=  39.4s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time=  39.5s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time=  39.5s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time=  39.2s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time=  39.2s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time=  39.3s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time=  39.2s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time=  39.3s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time=  39.5s
# {'leaf_size': 10, 'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# knn: 0.7751233958538993
# Accuracy: 77.51%, Logloss: 0.52
# 0.7804189732716663

# %%
for column in df_test.columns.tolist():
    df_test[column] = df_test[column].fillna(0)  

df_test= df_test.replace('', 0)

# %%
y_pred_knn = knn_.predict_proba(df_test)[:,1]
submission_knn = pd.DataFrame(data={'Opportunity_ID':df_test['Opportunity_ID'], 'Target': y_pred_knn})
submission_knn = submission_knn.groupby("Opportunity_ID").agg({"Target":"mean"}).reset_index()
submission_knn.to_csv('../submits/glmm_knn.csv', index=False)

# %%
y_pred_knn_norm = normalized_knn.predict_proba(df_test)[:,1]
submission_knn_norm = pd.DataFrame(data={'Opportunity_ID':df_test['Opportunity_ID'], 'Target': y_pred_knn_norm})
submission_knn_norm = submission_knn_norm.groupby("Opportunity_ID").agg({"Target":"mean"}).reset_index()
submission_knn_norm.to_csv('../submits/glmm_knn_norm.csv', index=False)
