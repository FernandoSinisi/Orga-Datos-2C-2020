# %%
import pandas as pd

from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score

from sklearn import model_selection, metrics, preprocessing, neighbors

# %%
df_train_mean_encoding = pd.read_csv('../../Feature_Encoding/data/train_mean_encoding.csv')
df_test_mean_encoding = pd.read_csv('../../Feature_Encoding/data/test_mean_encoding.csv')
train = pd.read_csv('../../Feature_Engineering/data/other-cleaned_train.csv')

# %%
def cross_val(model, x_train, y_train):
    score_cross_val = model_selection.cross_val_score(model, x_train, y_train, cv=5)
    print(score_cross_val.mean())

# %%
def test_model(model, x_test, y_test):
    predictions = model.predict_proba(x_test)[:,1]
    logloss = metrics.log_loss(y_test, predictions)
    accuracy = metrics.accuracy_score(y_test, predictions.round())
    print("Accuracy: %.2f%%, Logloss: %.2f" % (accuracy*100.0, logloss))

# %%
#Realiza busqueda completa combinando los parametros
def knn(x_train, y_train, x_validation, y_validation):
    knn_classifier = neighbors.KNeighborsClassifier()
    params_knn = {'weights':['uniform','distance'],'leaf_size':[10,15,30,45],'n_neighbors':[5,10,25,50],'p':[1,2,3,4]}    
    knn_gs = model_selection.GridSearchCV(knn_classifier, params_knn, cv=2,verbose=3)
    knn_gs.fit(x_train, y_train)
    knn_best = knn_gs.best_estimator_
    print(knn_gs.best_params_)
    print('knn: {}'.format(knn_best.score(x_validation, y_validation)))
    return knn_best

# %%
y = train.Target
x_train_mean_encoding, x_validation_mean_encoding, y_train_mean_encoding, y_validation_mean_encoding = model_selection.train_test_split(df_train_mean_encoding, y, test_size=0.3, stratify=y)

# %%
#Para normalizar las columnas
normalized_mean = preprocessing.normalize(df_train_mean_encoding,axis=0)

y = train.Target
normalized_x_train_mean_encoding, normalized_x_validation_mean_encoding, normalized_y_train_mean_encoding, normalized_y_validation_mean_encoding = model_selection.train_test_split(normalized_mean, y, test_size=0.3, stratify=y)

# %% [markdown]
# ## Mean encoding

# %%
knn_mean_encoding = knn(x_train_mean_encoding, y_train_mean_encoding, x_validation_mean_encoding, y_validation_mean_encoding)
test_model(knn_mean_encoding,x_validation_mean_encoding,y_validation_mean_encoding)
cross_val(knn_mean_encoding, x_train_mean_encoding, y_train_mean_encoding)
# Out:
# Fitting 2 folds for each of 128 candidates, totalling 256 fits
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   3.2s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   3.0s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   2.8s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   1.5s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time=  57.3s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time=  54.1s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time=  57.1s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time=  51.9s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time=  46.6s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time=  51.1s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time=  47.0s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time=  55.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   2.6s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   2.4s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   2.3s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   1.1s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time=  52.7s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time=  54.3s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time=  54.2s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time=  54.1s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time=  42.7s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time=  29.7s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time=  29.6s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time=  29.5s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   1.6s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   1.6s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   1.5s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time=  29.5s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time=  29.7s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time=  29.4s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time=  29.5s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time=  29.5s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time=  29.6s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time=  29.6s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time=  29.8s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   1.6s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   1.6s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   1.5s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   1.5s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time=  29.5s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time=  29.5s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time=  29.8s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time=  29.4s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time=  29.5s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time=  29.5s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time=  29.4s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time=  29.5s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   1.5s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   1.5s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   1.4s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time=  29.6s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time=  30.1s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time=  29.4s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time=  29.5s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time=  29.5s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time=  29.5s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time=  29.4s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time=  29.4s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   1.6s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   1.5s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   1.4s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time=  29.8s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time=  30.0s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time=  29.8s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time=  29.6s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time=  29.6s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time=  29.8s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time=  29.8s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time=  29.7s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   1.6s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   1.6s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   1.4s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   1.0s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time=  32.3s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time=  39.6s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time=  36.4s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time=  35.5s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time=  36.1s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time=  35.8s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time=  36.1s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time=  35.9s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   2.0s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   1.8s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   1.8s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   1.2s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   1.3s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time=  36.5s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time=  35.5s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time=  34.7s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time=  34.7s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time=  35.0s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time=  34.8s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time=  35.4s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time=  34.6s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   1.8s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time=  34.7s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time=  34.8s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time=  34.6s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time=  34.7s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time=  34.7s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time=  35.7s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time=  34.6s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time=  38.5s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   2.3s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   2.1s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   2.0s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   2.3s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   1.3s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   1.2s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   1.0s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time=  36.5s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time=  36.8s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time=  36.6s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time=  38.2s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time=  40.2s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time=  40.7s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time=  45.4s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time=  60.0s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   3.4s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   3.2s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   2.8s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   3.0s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   1.7s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   1.6s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   1.3s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   1.4s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time=  54.0s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time=  35.5s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time=  35.3s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time=  35.4s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time=  35.5s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time=  35.8s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time=  36.9s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time=  36.5s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   1.8s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   1.8s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   1.2s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   1.1s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time=  37.5s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time=  36.0s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time=  36.2s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time=  36.9s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time=  37.7s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time=  40.1s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time=  38.1s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time=  37.1s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   2.1s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   2.0s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   2.0s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   1.2s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time=  37.1s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time=  35.9s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time=  35.2s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time=  35.2s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time=  35.3s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time=  35.3s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time=  35.1s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time=  35.2s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   1.8s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   1.9s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   1.1s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   1.1s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   1.0s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   0.9s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time=  36.1s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time=  49.0s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time= 1.1min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time= 1.0min
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time= 1.0min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time= 1.0min
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time= 1.0min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time= 1.3min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   8.2s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   8.1s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   6.7s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   7.0s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   3.3s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   3.3s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   2.9s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   2.8s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time= 1.6min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time= 1.6min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time= 1.6min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time= 1.6min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time= 1.6min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time= 1.7min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time= 1.6min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time= 1.6min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   5.9s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   4.9s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   4.8s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   4.8s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   3.1s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   2.5s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   2.3s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time= 1.6min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time= 1.7min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time= 1.5min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time= 1.5min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time= 1.5min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time= 1.5min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time= 1.5min
# {'leaf_size': 10, 'n_neighbors': 50, 'p': 1, 'weights': 'distance'}
# knn: 0.7842053307008885
# Accuracy: 78.42%, Logloss: 0.46
# 0.776104109247687

# %%
normalized_knn_mean_encoding = knn(normalized_x_train_mean_encoding, normalized_y_train_mean_encoding, normalized_x_validation_mean_encoding, normalized_y_validation_mean_encoding)
test_model(normalized_knn_mean_encoding,normalized_x_validation_mean_encoding,normalized_y_validation_mean_encoding)
cross_val(normalized_knn_mean_encoding, normalized_x_train_mean_encoding, normalized_y_train_mean_encoding)
# Out:
# Fitting 2 folds for each of 128 candidates, totalling 256 fits
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   4.8s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=uniform; total time=   4.8s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   4.8s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=1, weights=distance; total time=   4.8s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   2.8s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=uniform; total time=   2.4s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   2.0s
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=2, weights=distance; total time=   1.9s
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time= 1.5min
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=uniform; total time= 1.5min
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time= 1.5min
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=3, weights=distance; total time= 1.5min
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time= 1.5min
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=uniform; total time= 1.5min
# [CV 1/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=5, p=4, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   4.2s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=uniform; total time=   4.1s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   3.7s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=1, weights=distance; total time=   4.1s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   2.5s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=uniform; total time=   2.5s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   2.0s
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=2, weights=distance; total time=   2.0s
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=3, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=10, p=4, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   3.9s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=uniform; total time=   4.3s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   3.8s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=1, weights=distance; total time=   3.9s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   2.4s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=uniform; total time=   2.4s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   1.9s
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=2, weights=distance; total time=   1.7s
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=3, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time= 1.5min
# [CV 2/2] END leaf_size=10, n_neighbors=25, p=4, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   4.1s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=uniform; total time=   4.7s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   4.0s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=1, weights=distance; total time=   3.9s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   2.5s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=uniform; total time=   2.4s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   1.9s
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=2, weights=distance; total time=   2.1s
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=uniform; total time= 1.5min
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=3, weights=distance; total time= 1.5min
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time= 1.5min
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=10, n_neighbors=50, p=4, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   4.5s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=uniform; total time=   4.3s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   3.8s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=1, weights=distance; total time=   3.9s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   2.3s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=uniform; total time=   2.1s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   1.8s
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=2, weights=distance; total time=   1.8s
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=3, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=5, p=4, weights=distance; total time= 1.5min
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   4.3s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=uniform; total time=   3.8s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   3.9s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=1, weights=distance; total time=   4.0s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   2.3s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=uniform; total time=   2.4s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   2.1s
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=2, weights=distance; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=3, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=10, p=4, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   4.4s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=uniform; total time=   4.1s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   3.7s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=1, weights=distance; total time=   4.1s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   2.3s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=uniform; total time=   2.4s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   2.2s
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=2, weights=distance; total time=   1.9s
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=uniform; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time= 1.4min
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=3, weights=distance; total time= 1.4min
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time= 1.5min
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=uniform; total time= 1.6min
# [CV 1/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time= 1.5min
# [CV 2/2] END leaf_size=15, n_neighbors=25, p=4, weights=distance; total time= 1.5min
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   5.0s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=uniform; total time=   4.7s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   4.1s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=1, weights=distance; total time=   3.9s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   2.6s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=uniform; total time=   2.5s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   2.7s
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=2, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time= 1.5min
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=uniform; total time= 1.5min
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time= 1.5min
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=3, weights=distance; total time= 1.6min
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time= 1.7min
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=uniform; total time= 1.9min
# [CV 1/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=15, n_neighbors=50, p=4, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   5.3s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=   5.5s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   4.9s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=   4.7s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   2.5s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=   2.6s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=   2.6s
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=uniform; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time= 1.7min
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=3, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time= 1.7min
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=uniform; total time= 1.7min
# [CV 1/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=5, p=4, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   5.3s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=   5.6s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   4.9s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=   4.9s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   2.8s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=   2.9s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=   2.3s
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=uniform; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=3, weights=distance; total time= 1.7min
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=uniform; total time= 1.7min
# [CV 1/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=10, p=4, weights=distance; total time= 1.7min
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   6.2s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=uniform; total time=   5.3s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   4.8s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=1, weights=distance; total time=   5.2s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   2.9s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=uniform; total time=   2.7s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   2.4s
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=2, weights=distance; total time=   2.3s
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time= 1.9min
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=uniform; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=3, weights=distance; total time= 1.7min
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time= 1.9min
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=uniform; total time= 2.2min
# [CV 1/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time= 2.1min
# [CV 2/2] END leaf_size=30, n_neighbors=25, p=4, weights=distance; total time= 2.0min
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   4.9s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=uniform; total time=   4.6s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   4.7s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=1, weights=distance; total time=   4.6s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   2.7s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=uniform; total time=   2.6s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   2.6s
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=2, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time= 1.7min
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=uniform; total time= 1.6min
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=3, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time= 1.8min
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=uniform; total time= 1.9min
# [CV 1/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=30, n_neighbors=50, p=4, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   5.2s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=uniform; total time=   5.1s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   4.5s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=1, weights=distance; total time=   5.2s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   2.9s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=uniform; total time=   2.6s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   2.3s
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=2, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time= 1.8min
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=uniform; total time= 1.8min
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time= 1.8min
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=3, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time= 1.7min
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=uniform; total time= 1.8min
# [CV 1/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time= 1.8min
# [CV 2/2] END leaf_size=45, n_neighbors=5, p=4, weights=distance; total time= 1.8min
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   5.1s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=uniform; total time=   5.2s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   4.9s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=1, weights=distance; total time=   4.8s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   3.0s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=uniform; total time=   2.9s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   2.5s
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=2, weights=distance; total time=   2.2s
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time= 1.8min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=uniform; total time= 1.8min
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time= 2.0min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=3, weights=distance; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=uniform; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=10, p=4, weights=distance; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   6.1s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=uniform; total time=   5.4s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   5.5s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=1, weights=distance; total time=   5.1s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   2.8s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=uniform; total time=   2.8s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   2.6s
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=2, weights=distance; total time=   2.5s
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time= 2.0min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=uniform; total time= 2.0min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=3, weights=distance; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=uniform; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=25, p=4, weights=distance; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   5.1s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=uniform; total time=   5.1s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   5.0s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=1, weights=distance; total time=   4.9s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   2.9s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=uniform; total time=   3.1s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   2.8s
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=2, weights=distance; total time=   2.7s
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time= 2.0min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=uniform; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=3, weights=distance; total time= 1.9min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time= 1.9min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=uniform; total time= 2.0min
# [CV 1/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time= 2.0min
# [CV 2/2] END leaf_size=45, n_neighbors=50, p=4, weights=distance; total time= 1.9min
# {'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# knn: 0.9036525172754195
# Accuracy: 90.37%, Logloss: 0.71
# 0.900659955761876

# %%
y_pred_knn_mean = knn_mean_encoding.predict_proba(df_test_mean_encoding)[:,1]
submission_knn_mean = pd.DataFrame(data={'Opportunity_ID':df_test_mean_encoding['Opportunity_ID'], 'Target': y_pred_knn_mean})
submission_knn_mean = submission_knn_mean.groupby("Opportunity_ID").agg({"Target":"mean"}).reset_index()
submission_knn_mean.to_csv('../submits/mean_knn.csv', index=False)

# %%
y_pred_knn_mean_norm = normalized_knn_mean_encoding.predict_proba(df_test_mean_encoding)[:,1]
submission_knn_mean_norm = pd.DataFrame(data={'Opportunity_ID':df_test_mean_encoding['Opportunity_ID'], 'Target': y_pred_knn_mean_norm})
submission_knn_mean_norm = submission_knn_mean_norm.groupby("Opportunity_ID").agg({"Target":"mean"}).reset_index()
submission_knn_mean_norm.to_csv('../submits/mean_knn_norm.csv', index=False)
